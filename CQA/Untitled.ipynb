# %%
import pandas as pd

# %%
df = pd.read_csv('revised.csv')

# %%
df.head()
# Out:
#    common_word_cnt  common_nonstop_word_cnt  char_cnt_1  char_cnt_2  \
# 0                4                        3          57          54
# 1                1                        1          33          54
# 2                1                        0          40          54
# 3                4                        3          57          54
# 4                0                        0          25          54
#
#    char_cnt_diff  word_cnt_1  word_cnt_2  word_cnt_diff  len_q1  len_q2  \
# 0              9           9           9              0      57      54
# 1            441           6           9              9      33      54
# 2            196           8           9              1      40      54
# 3              9           9           9              0      57      54
# 4            841           4           9             25      25      54
#
#           ...          fuzz_qratio  fuzz_WRatio  fuzz_partial_ratio  \
# ...
